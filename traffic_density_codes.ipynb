# %%
from keplergl import KeplerGl
map_202007=KeplerGl(height=900)
with open ('traffic_density_202007.csv', 'r') as f:
    csvData =f.read()
map_202007.add_data(data=csvData, name=('data_202007'))
map_202007
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data_202007': 'DATE_TIME,LONGITUDE,LATITUDE,GEOHASH,MINIMUM_SPEED,MAXIMUM_SPEED,AVERAGE_SPEED,…

# %%
from keplergl import KeplerGl
map_202008=KeplerGl(height=900)
with open ('traffic_density_202008.csv', 'r') as f:
    csvData =f.read()
map_202008.add_data(data=csvData, name=('data_202008'))
map_202008
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data_202008': 'DATE_TIME,LONGITUDE,LATITUDE,GEOHASH,MINIMUM_SPEED,MAXIMUM_SPEED,AVERAGE_SPEED,…

# %%
from keplergl import KeplerGl
map_202009=KeplerGl(height=900)
with open ('traffic_density_202009.csv', 'r') as f:
    csvData =f.read()
map_202009.add_data(data=csvData, name=('data_202009'))
map_202009
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data_202009': 'DATE_TIME,LONGITUDE,LATITUDE,GEOHASH,MINIMUM_SPEED,MAXIMUM_SPEED,AVERAGE_SPEED,…

# %%
from keplergl import KeplerGl
map_202010=KeplerGl(height=900)
with open ('traffic_density_202010.csv', 'r') as f:
    csvData =f.read()
map_202010.add_data(data=csvData, name=('data_202010'))
map_202010
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data_202010': 'DATE_TIME,LONGITUDE,LATITUDE,GEOHASH,MINIMUM_SPEED,MAXIMUM_SPEED,AVERAGE_SPEED,…

# %%
from keplergl import KeplerGl
map_202011=KeplerGl(height=900)
with open ('traffic_density_202011.csv', 'r') as f:
    csvData =f.read()
map_202011.add_data(data=csvData, name=('data_202011'))
map_202011
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data_202011': 'DATE_TIME,LONGITUDE,LATITUDE,GEOHASH,MINIMUM_SPEED,MAXIMUM_SPEED,AVERAGE_SPEED,…

# %%
from keplergl import KeplerGl
map_202012=KeplerGl(height=900)
with open ('traffic_density_202012.csv', 'r') as f:
    csvData =f.read()
map_202012.add_data(data=csvData, name=('data_202012'))
map_202012
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data_202012': 'DATE_TIME,LONGITUDE,LATITUDE,GEOHASH,MINIMUM_SPEED,MAXIMUM_SPEED,AVERAGE_SPEED,…

# %%
from keplergl import KeplerGl
map_202101=KeplerGl(height=900)
with open ('traffic_density_202101.csv', 'r') as f:
    csvData =f.read()
map_202101.add_data(data=csvData, name=('data_202101'))
map_202101
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data_202101': 'DATE_TIME,LONGITUDE,LATITUDE,GEOHASH,MINIMUM_SPEED,MAXIMUM_SPEED,AVERAGE_SPEED,…
